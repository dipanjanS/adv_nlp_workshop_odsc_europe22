# %% [markdown]
# # Document Clustering with Transformers
#
# ![](https://i.imgur.com/7SXKckD.png)
#
# Transfer Learning is the power of leveraging already trained models and tune \ adapt them to our own downstream tasks.

# %% [markdown]
# # Finding similar clusters of documents with Transformer embeddings
#
# Here we will leverage already pre-trained Transformer models extract embeddings from documents and leverage unsupervised clustering models to group documents together
#
#
#
# # Clustering
#
# The idea of clustering is to group similar documents together based on the similarity of their embeddings
#
# ![](https://i.imgur.com/KaF70Ow.png)

# %% [markdown]
# # Clustering with Transformers and Agglomerative Clustering
#
# Here we use Hierarchical clustering using the Agglomerative Clustering Algorithm.
#
# In contrast to k-means, we can specify a threshold for the clustering: Clusters below that threshold are merged.
#
# This algorithm can be useful if the number of clusters is unknown.
#
# By the threshold, we can control if we want to have many small and fine-grained clusters or few coarse-grained clusters.

# %%
# !pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 4.0 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.19.4-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 17.4 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.12.0+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 48.7 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.8 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.6.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (4.11.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.7.1)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 64.7 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.23.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 59.7 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.8.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=ad2f74e2e253f15f1ee0556c890e9ca2f23844c9473919e4a1a564b6c9b165f4
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# Successfully built sentence-transformers
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers, sentencepiece, sentence-transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.7.0 pyyaml-6.0 sentence-transformers-2.2.0 sentencepiece-0.1.96 tokenizers-0.12.1 transformers-4.19.4

# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import AgglomerativeClustering
import numpy as np

# %%
# Corpus with example sentences
corpus = ['A man is eating food.',
          'A man is eating a piece of bread.',
          'A man is eating pasta.',
          'The girl is carrying a baby.',
          'The baby is carried by the woman',
          'A man is riding a horse.',
          'A man is riding a white horse on an enclosed ground.',
          'A monkey is playing drums.',
          'Someone in a gorilla costume is playing a set of drums.',
          'A cheetah is running behind its prey.',
          'A cheetah chases prey on across a field.'
          ]

# %%
# https://huggingface.co/microsoft/MiniLM-L12-H384-uncased
# MiniLM: Small and Fast Pre-trained Models for Language Understanding and Generation
# MiniLMv1-L12-H384-uncased: 12-layer, 384-hidden, 12-heads, 33M parameters, 2.7x faster than BERT-Base

embedder = SentenceTransformer('all-MiniLM-L12-v2')
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/573 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/134M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/352 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
corpus_embeddings = embedder.encode(corpus)

# %%
corpus_embeddings[0], corpus_embeddings[0].shape
# Out:
# (array([-2.29966976e-02, -5.42215668e-02, -4.23413068e-02, -4.47488800e-02,
#         -3.54231820e-02, -2.26035714e-02,  6.13889731e-02, -1.12497553e-01,
#         -8.98872688e-02, -3.51876067e-03,  4.92821187e-02,  1.29731558e-02,
#         -8.50402489e-02,  3.15274554e-03,  5.85234836e-02, -4.41259705e-02,
#          9.25420448e-02,  6.59015775e-03,  1.15228839e-01, -1.57639496e-02,
#          5.49910143e-02,  4.11766060e-02, -1.19129522e-02, -1.44276749e-02,
#          3.10340170e-02, -1.60162505e-02,  4.61587384e-02,  1.46778105e-02,
#         -1.98512543e-02,  1.25952065e-02,  5.77107556e-02, -3.58901843e-02,
#          3.83329540e-02,  6.27230257e-02, -2.96712387e-02, -3.16205248e-03,
#         -1.50016574e-02, -5.01024313e-02,  3.76782604e-02,  2.17826362e-03,
#          3.49687226e-02,  4.41790484e-02,  6.48202701e-03,  1.21949818e-02,
#         -1.04580205e-02,  4.10641804e-02, -1.24173544e-01,  7.04240799e-02,
#          5.61078265e-02,  3.16133052e-02, -1.63872033e-01,  5.93387745e-02,
#          7.05524534e-02,  4.91676666e-02,  8.16122815e-02, -1.12351924e-02,
#         -3.70220318e-02,  7.42088165e-03, -9.57428217e-02, -3.36694978e-02,
#          6.62841229e-03, -4.97205928e-02,  1.84414238e-02, -1.38200596e-02,
#          3.82310301e-02, -2.42912453e-02, -1.63757913e-02,  6.06745621e-03,
#          3.65076549e-02,  3.48668247e-02, -4.16562259e-02, -9.75515787e-03,
#          3.62850651e-02, -2.81292517e-02,  1.00933593e-02, -1.79464519e-02,
#         -5.76705150e-02, -7.78197916e-03, -3.26066315e-02,  1.15049727e-01,
#         -4.10646014e-02,  7.64844194e-02, -2.62457412e-02, -1.98698696e-02,
#         -7.06553310e-02, -1.28001571e-02, -9.53501016e-02,  2.55336054e-02,
#          1.78501178e-02,  1.11320399e-01,  6.39902800e-03, -2.45363880e-02,
#          4.78147455e-02,  3.69591005e-02,  6.13196641e-02, -3.07677351e-02,
#         -1.44793447e-02, -7.07744509e-02, -1.23132206e-01, -1.15354257e-02,
#         -6.52747462e-03, -3.86469401e-02, -1.25186918e-02,  2.27603945e-03,
#          5.84791899e-02,  3.38717438e-02, -1.58771258e-02,  5.99246919e-02,
#         -1.75329186e-02, -1.98470131e-02,  2.18995269e-02,  9.21519920e-02,
#         -4.79302853e-02, -4.96542007e-02, -2.78532729e-02,  3.76009978e-02,
#         -2.69096047e-02, -5.35383448e-02, -4.06361036e-02,  1.23616681e-02,
#          2.89887451e-02,  4.95163798e-02, -5.93000762e-02,  5.96112646e-02,
#         -2.24290397e-02,  3.70429195e-02,  8.31070766e-02,  4.02411781e-02,
#         -1.27526522e-02, -8.29768255e-02,  3.78078669e-02, -4.92756478e-02,
#          3.95677760e-02,  1.85041819e-02, -2.23389585e-02, -2.84447018e-02,
#          8.27409029e-02, -6.76813945e-02,  3.09390370e-02,  2.23472714e-02,
#         -1.76080186e-02,  8.68975148e-02, -7.10687265e-02, -5.75348549e-02,
#         -1.53680807e-02,  6.67256564e-02,  7.47839883e-02, -3.73784192e-02,
#         -9.36229825e-02, -5.17806858e-02,  7.41156489e-02,  2.56233625e-02,
#         -3.16113345e-02, -3.16437148e-02, -4.96922657e-02,  6.31725509e-03,
#          2.72681024e-02, -4.91089188e-02, -2.43696338e-03,  6.92708418e-02,
#         -2.67709568e-02, -3.03302892e-02,  6.42358139e-02, -7.27256685e-02,
#         -9.89437290e-03,  5.11909537e-02, -2.52400655e-02, -6.09888975e-03,
#          7.14383870e-02,  2.13818308e-02,  2.44772322e-02,  3.18588763e-02,
#         -1.03468783e-01, -1.68038439e-02, -1.33376953e-03,  9.72915366e-02,
#          6.14428753e-03, -3.46681736e-02,  1.18012413e-01, -7.19276145e-02,
#         -2.39572637e-02, -6.77998960e-02,  6.05089255e-02, -9.77739096e-02,
#          8.39354694e-02,  3.48533764e-02,  4.83851554e-03,  9.01399627e-02,
#         -1.42807076e-02,  1.45101780e-02,  7.27061629e-02,  1.72486564e-03,
#         -6.15223125e-02, -1.22315772e-01, -5.75338155e-02, -9.33362469e-02,
#          6.44984748e-03,  1.93843544e-02,  3.91344056e-02, -9.05237719e-02,
#          1.22270826e-02, -6.04795292e-02, -4.48255539e-02, -7.23024011e-02,
#         -3.28071509e-03, -3.29119489e-02, -1.60891600e-02,  2.68827332e-03,
#          2.86784396e-02,  4.90302546e-03,  7.00606927e-02,  8.14573467e-03,
#         -5.89302070e-02,  1.63865224e-01, -5.98960137e-03,  1.11517655e-02,
#          1.49597466e-01,  1.82550624e-02, -2.50185113e-02, -1.45353563e-02,
#         -2.55793519e-02,  6.21747337e-02,  1.91413518e-02,  1.25239181e-32,
#         -8.54057521e-02,  2.68388968e-02, -1.81362517e-02,  3.33571993e-02,
#          2.35469211e-02, -2.96525024e-02, -3.63724492e-02,  2.45269407e-02,
#         -3.38206626e-02, -7.35579059e-02,  7.47724846e-02,  1.20141163e-01,
#          9.65038911e-02,  3.67118679e-02,  3.10467929e-02,  5.03351018e-02,
#         -3.62701304e-02, -8.09453577e-02, -9.89548489e-03, -7.98202083e-02,
#         -1.77425556e-02, -4.17251745e-03,  5.29893674e-02, -1.56454351e-02,
#         -3.42388451e-03,  9.20621976e-02,  1.95606425e-02,  5.40848859e-02,
#          6.12091972e-04, -1.40643101e-02,  6.81590885e-02, -2.99224742e-02,
#          8.03646743e-02, -9.29247737e-02,  7.51136839e-02,  5.04919477e-02,
#         -5.17198518e-02,  7.01731769e-04, -5.49481921e-02,  6.76507801e-02,
#         -3.00676189e-02,  1.09721683e-01,  5.94596639e-02,  5.66282012e-02,
#          1.77434534e-02, -1.23989880e-02, -1.40022440e-02, -5.96641377e-03,
#         -3.60405855e-02,  9.44631249e-02,  6.54963776e-02, -1.01172989e-02,
#         -1.30008692e-02, -2.51380652e-02, -3.90573032e-02,  9.11107585e-02,
#         -9.12920758e-02,  4.25892025e-02, -4.62158658e-02, -5.32227010e-02,
#          8.55805352e-03, -2.73265783e-02,  2.48462949e-02, -2.55772900e-02,
#         -2.02640090e-02,  2.60106940e-02, -4.49861586e-02, -1.80920567e-02,
#         -5.95825375e-04,  6.64997054e-03,  1.64632425e-02,  1.32728564e-02,
#          5.12793995e-02, -4.70716543e-02,  1.60518885e-02,  4.92517762e-02,
#         -1.84742305e-02, -7.69938761e-03, -1.33930454e-02, -3.28658498e-03,
#         -3.32558528e-02,  5.56745008e-02, -3.40803452e-02, -3.87951806e-02,
#         -2.63442062e-02,  1.20216738e-02, -2.31707729e-02, -6.80369558e-04,
#          1.46598062e-02,  6.17604107e-02, -3.70086133e-02, -8.56000334e-02,
#         -2.16063708e-02,  6.02633469e-02,  6.00129925e-02, -1.30767928e-32,
#          4.52870950e-02, -7.10760579e-02, -4.53845523e-02,  3.73097099e-02,
#          2.16093678e-02,  3.86346169e-02, -2.67422814e-02, -8.92196670e-02,
#          4.57401760e-02, -3.41228372e-03, -5.19791842e-02,  7.68494084e-02,
#          1.09898243e-02,  6.16256483e-02, -6.57359511e-02, -5.97925410e-02,
#          6.29333407e-02, -4.36701663e-02, -3.79009545e-02,  3.12860794e-02,
#         -1.54186143e-02,  5.72656132e-02, -3.18592601e-02, -2.79480685e-02,
#          8.26147348e-02, -1.66151824e-03,  2.40806956e-02,  5.97328916e-02,
#          8.00331756e-02, -2.19326988e-02,  1.29178753e-02,  4.03291434e-02,
#         -2.88015250e-02,  2.39055455e-02,  3.44637670e-02, -2.38823326e-04,
#         -5.77636510e-02,  1.13761071e-02,  5.26727289e-02,  1.03317471e-02,
#         -1.11123892e-02, -1.31512638e-02,  1.52838789e-02, -4.33441512e-02,
#          1.35769218e-03,  7.46176019e-02, -2.83303522e-02,  8.12500529e-03,
#          5.83418459e-02,  5.60758933e-02, -8.47064108e-02, -1.81452539e-02,
#          1.50530590e-02, -4.80306670e-02,  7.02512870e-03, -6.86838403e-02,
#          7.39512444e-02,  1.71164628e-02,  9.31148753e-02, -4.42212559e-02,
#          3.12821381e-02, -1.18074007e-03, -5.03916442e-02, -4.85660285e-02],
#        dtype=float32), (384,))

# %%
# Normalize the embeddings to unit length
corpus_embeddings = corpus_embeddings /  np.linalg.norm(corpus_embeddings, axis=1, keepdims=True)

# %%
clustering_model = AgglomerativeClustering(n_clusters=None, distance_threshold=1.5)
clustering_model.fit(corpus_embeddings)
cluster_assignment = clustering_model.labels_

# %%
clustered_sentences = {}
for sentence_id, cluster_id in enumerate(cluster_assignment):
    if cluster_id not in clustered_sentences:
        clustered_sentences[cluster_id] = []

    clustered_sentences[cluster_id].append(corpus[sentence_id])

# %%
for i, cluster in clustered_sentences.items():
    print("Cluster ", i+1)
    print(cluster)
    print("")
# Out:
# Cluster  1
# ['A man is eating food.', 'A man is eating a piece of bread.', 'A man is eating pasta.']
#
# Cluster  3
# ['The girl is carrying a baby.', 'The baby is carried by the woman']
#
# Cluster  5
# ['A man is riding a horse.', 'A man is riding a white horse on an enclosed ground.']
#
# Cluster  2
# ['A monkey is playing drums.', 'Someone in a gorilla costume is playing a set of drums.']
#
# Cluster  4
# ['A cheetah is running behind its prey.', 'A cheetah chases prey on across a field.']

# %% [markdown]
# # Large Scale Clustering with Transformers and Fast Clustering
#
# Agglomerative Clustering for larger datasets is quite slow, so it is only applicable for maybe a few thousand sentences.
#
# Sentence Transformers has a clustering algorithm that is tuned for large datasets (50k sentences in less than 5 seconds). In a large list of sentences it searches for local communities: A local community is a set of highly similar sentences.
#
# You can configure the threshold of cosine-similarity for which we consider two sentences as similar. Also, you can specify the minimal size for a local community. This allows you to get either large coarse-grained clusters or small fine-grained clusters.

# %% [markdown]
# ## Get Duplicate Questions Quora Dataset

# %%
import os
import csv
import time
from sentence_transformers import util

# We donwload the Quora Duplicate Questions Dataset (https://www.quora.com/q/quoradata/First-Quora-Dataset-Release-Question-Pairs)
# and find similar question in it
url = "http://qim.fs.quoracdn.net/quora_duplicate_questions.tsv"
dataset_path = "quora_duplicate_questions.tsv"
max_corpus_size = 50000 # We limit our corpus to only the first 50k questions


# Check if the dataset exists. If not, download and extract
# Download dataset if needed
if not os.path.exists(dataset_path):
    print("Download dataset")
    util.http_get(url, dataset_path)

# Get all unique sentences from the file
corpus_sentences = set()
with open(dataset_path, encoding='utf8') as fIn:
    reader = csv.DictReader(fIn, delimiter='\t', quoting=csv.QUOTE_MINIMAL)
    for row in reader:
        corpus_sentences.add(row['question1'])
        corpus_sentences.add(row['question2'])
        if len(corpus_sentences) >= max_corpus_size:
            break

corpus_sentences = list(corpus_sentences)
# Out:
# Download dataset
#   0%|          | 0.00/58.2M [00:00<?, ?B/s]

# %%
len(corpus_sentences)
# Out:
# 50001

# %%
corpus_sentences[:5]
# Out:
# ['Which are the best TV series to watch?',
#  "Why are women who are on their periods are regarded as 'unclean' such that they are prevented in taking an actived part in rituals (Hinduism)?",
#  'What are good online high schools and how do they work?',
#  'How do I help the pro-life movement?',
#  'Why do I want to be with someone always, otherwise I am feeling depressed?']

# %% [markdown]
# ## Generate Document Embeddings

# %%
print("Encode the corpus. This might take a while")
corpus_embeddings = embedder.encode(corpus_sentences, batch_size=64, show_progress_bar=True, convert_to_tensor=True)
# Out:
# Encode the corpus. This might take a while
# Batches:   0%|          | 0/782 [00:00<?, ?it/s]

# %% [markdown]
# ## Cluster documents with Community Detection Model

# %%
print("Start clustering")
start_time = time.time()

#Two parameters to tune:
#min_cluster_size: Only consider cluster that have at least 25 elements
#threshold: Consider sentence pairs with a cosine-similarity larger than threshold as similar
clusters = util.community_detection(corpus_embeddings, min_community_size=25, threshold=0.75)

print("Clustering done after {:.2f} sec".format(time.time() - start_time))
# Out:
# Start clustering
# Clustering done after 3.67 sec

# %%
#Print for all clusters the top 3 and bottom 3 elements
for i, cluster in enumerate(clusters):
    print("\nCluster {}, #{} Elements ".format(i+1, len(cluster)))
    for sentence_id in cluster[0:3]:
        print("\t", corpus_sentences[sentence_id])
    print("\t", "...")
    for sentence_id in cluster[-3:]:
        print("\t", corpus_sentences[sentence_id])
# Out:
# Cluster 1, #101 Elements
# 	 How can I improve my spoken English ability?
# 	 How can I improve my English speaking ability?
# 	 How can I improve my spoken English?
# 	 ...
# 	 What should I have to do to make my english and communication skills perfect?
# 	 How can I improve my English speaking skills as well as writing skills?
# 	 How can I improve my fluency in English to face a more confortable job interview?
#
# Cluster 2, #97 Elements
# 	 How can one make money online?
# 	 How could I make money online?
# 	 What is a way to make money online?
# 	 ...
# 	 What are the ways to make money working from home?
# 	 How can l earn $100 online daily?
# 	 Make money online from Nigeria?
#
# Cluster 3, #89 Elements
# 	 How will the 500 & 1000 rupee note ban affect India?
# 	 How will India be affected now that 500 and 1000 rupee notes have been banned?
# 	 What effect will the rupee 500 and 1000 currency note ban have on the Indian economy?
# 	 ...
# 	 What do you think about Modi government banning 500 & 1000 currency note from 9th November?
# 	 Why the Modi government ban the 500 and 1000 notes?
# 	 What are your views on the ban of Rs 500 and Rs 1000 notes by the Indian Government? Pros cons?
#
# Cluster 4, #75 Elements
# 	 What are some things new employees should know going into their first day at Zogenix?
# 	 What are some things new employees should know going into their first day at Cyan?
# 	 What are some things new employees should know going into their first day at Epizyme?
# 	 ...
# 	 What are some things new employees should know going into their first day at AT&T?
# 	 What are some things new employees should know going into their first day at Northern Oil & Gas?
# 	 What are some things new employees should know going into their first day at NVIDIA?
#
# Cluster 5, #68 Elements
# 	 What is the best language to learn programming?
# 	 What is the best programming/coding language to learn?
# 	 What is the best programming language to learn(in your opinion)?
# 	 ...
# 	 What is the best language to learn to start: Java, C, or C++?
# 	 What is the most important programming language for getting a good job in any company?
# 	 How do I start learning to code? Also,which programming language is recommended for beginners?
#
# Cluster 6, #67 Elements
# 	 What is a suitable inpatient drug and alcohol rehab center near Marion County IN?
# 	 Which is a suitable inpatient drug and alcohol rehab center near Johnson County IN?
# 	 Which is a suitable inpatient drug and alcohol rehab center near Marshall County IN?
# 	 ...
# 	 Is there a Drug and Alcohol Rehab Center in Bristol Bay County AK?
# 	 Is there a Drug and Alcohol Rehab Center in Juneau County AK?
# 	 Is there a Drug and Alcohol Rehab Center in Anchorage County AK?
#
# Cluster 7, #55 Elements
# 	 Why does Quora always marks my question as needing improvement?
# 	 Why does Quora always mark my questions as needing improvement?
# 	 Why does quora mark my questions as needing improvement?
# 	 ...
# 	 The question was marked as needing improvement. Just now?
# 	 My questions haven't changed. Why are they now being marked as needing improvement?
# 	 How should I edit my question correctly if Quora marks down my question for improvement?
#
# Cluster 8, #53 Elements
# 	 What is the fastest way to lose weight?
# 	 What is the fastest possible way to lose weight?
# 	 What is the quickest possible way to lose weight?
# 	 ...
# 	 What is the most effective everlasting method of losing weight?
# 	 How can you rapidly lose weight in 14days?
# 	 How can I lose weight safely?
#
# Cluster 9, #51 Elements
# 	 How can you increase your height?
# 	 How could I increase my height?
# 	 How do I increase my height?
# 	 ...
# 	 Is it possible to increase the body height after 20?
# 	 How do I get taller even though I am 6 foot?
# 	 Has anyone got any results from height increasing techniques?
#
# Cluster 10, #49 Elements
# 	 Why do people bother to ask questions on Quora they could just google to get the answer?
# 	 Why do people often ask questions in Quora while they can Google it themselves?
# 	 Why do so many people ask things on Quora that they could just as easily Google?
# 	 ...
# 	 How come people on Quora ask questions here, when they can get them on Google and why is Quora just a question/answer site, will it expand?
# 	 Is it bad to ask questions on Quora that could easily be answered via a Google search?
# 	 Why do people ask questions on Quora that are easily answerable via a quick internet search?
#
# Cluster 11, #49 Elements
# 	 How do I reduce my belly fat easily?
# 	 Whats the best way to reduce belly fat?
# 	 How do I reduce belly fat in minimal time?
# 	 ...
# 	 What daily quick exercise can help reduce belly & thigh's Fat?
# 	 How do I lose stomach and chest fat?
# 	 How can I reduce my weight and tummy?
#
# Cluster 12, #49 Elements
# 	 How Can You Recover Your Gmail Password?
# 	 How can you recover your Gmail password?
# 	 How do you recover your Gmail password?
# 	 ...
# 	 How do I reset a Gmail password without a phone number?
# 	 I forgot my Gmail password and the alternative mail ID (Yahoo) password too. What can I do to retrieve any of the passwords?
# 	 Can I recover my email if I forgot the password?
#
# Cluster 13, #45 Elements
# 	 What is the purpose of life?
# 	 What is the purpose of life ?
# 	 What's the purpose of life?
# 	 ...
# 	 What's are the meaning of life?
# 	 What is the exact meaning of life?
# 	 What is the meaning that the "purpose of life is 42"?
#
# Cluster 14, #43 Elements
# 	 Is world war 3 likely?
# 	 Is there any chance of World War III?
# 	 Is World War 3 coming?
# 	 ...
# 	 Are we on the brink of a Third World War?
# 	 Is the ongoing war in Syria is the start of World War 3?
# 	 Will a world war ever happen again?
#
# Cluster 15, #42 Elements
# 	 Will Pakistan have a war with India?
# 	 Will India fight a war with Pakistan?
# 	 Will war happen between India and Pakistan?
# 	 ...
# 	 Who would win an all out war between Pakistan and India if no other country got involved?
# 	 Should India declare war against Pakistan as they are spreading terrorism in India?
# 	 Who would win a war between Pakistan and Australia?
#
# Cluster 16, #41 Elements
# 	 What is a good solar panel installation provider in San Carlos, California CA?
# 	 What is a suitable solar panel installation provider near San Fernando, California CA?
# 	 What is a good solar panel installation provider in San Bruno, California CA?
# 	 ...
# 	 What is a suitable solar panel installation provider near Laveen, Arizona AZ?
# 	 What is a suitable solar panel installation provider near Prescott, Arizona AZ?
# 	 What is a suitable solar panel installation provider in Yuma, Arizona AZ?
#
# Cluster 17, #41 Elements
# 	 Which is the best phone under 15000 Rs.?
# 	 Which is the best phone to buy within Rs.15000?
# 	 Which is the best phone to buy under Rs.1500?
# 	 ...
# 	 Which mobile is better under 15k?
# 	 Which is best smartphone under rs4000?
# 	 Which is the best phone of 2015?
#
# Cluster 18, #40 Elements
# 	 What is the easiest pain free method of committing suicide?
# 	 What is the easiest and most painless suicide method?
# 	 What is the easiest and painless way to commit suicide?
# 	 ...
# 	 How do I kill myself without it hurting?
# 	 Besides hanging yourself what are other ways people commit suicide?
# 	 What is the best way to commit suicide in India?
#
# Cluster 19, #40 Elements
# 	 Who will win the 2016 United States Presidential election: Trump or Clinton?
# 	 Who will win the Election? Trump or Clinton?
# 	 Who will win, Trump or Clinton?
# 	 ...
# 	 Who will win the election in united states?
# 	 Who do you think will win the Clinton-Trump debates?
# 	 Which candidate is currently projected to win the 2016 election at this time?
#
# Cluster 20, #39 Elements
# 	 What hotel in Surat would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?
# 	 What hotel in Fatehpur would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?
# 	 What hotel in Indore would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?
# 	 ...
# 	 What hotel in Jaipur would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?
# 	 What hotel in Nepal would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?
# 	 What hotel in Araku Valley Hill-station would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?
#
# Cluster 21, #39 Elements
# 	 How can I gain weight?
# 	 How do I gain weight?
# 	 How to gain weight ?
# 	 ...
# 	 Which is the best food to gain weight?
# 	 Can any one suggest the best foods for gaining weight?
# 	 I'm 15 year old my height is 5 feet 7 inches and my weight is 50 kg what should I do to gain weight?
#
# Cluster 22, #38 Elements
# 	 Is time travel possible?
# 	 Time Travel Is It Possible?
# 	 Can time travel ever be possible?
# 	 ...
# 	 Is time travel a paradox in and of itself?
# 	 Does the fact that nobody has ever visited us from the future mean that time travel is undoubtedly impossible?
# 	 Is time traval possible in future?
#
# Cluster 23, #37 Elements
# 	 How do I control my emotions and anger?
# 	 How can I control on my anger?
# 	 How can I control my anger?
# 	 ...
# 	 How do I control anger in office?
# 	 What are some effective ways to curb your anger?
# 	 What should I do to overcome my anger?
#
# Cluster 24, #36 Elements
# 	 What is your new year resolution, short term and long term goal for 2017?
# 	 What is your new year resolution for 2017 or goal for 2017?
# 	 What are your New Years resolutions for 2017?
# 	 ...
# 	 What's your new year resolution do or not to do?
# 	 What will be your 2017 resolution?
# 	 What's your resolution for year 2016?
#
# Cluster 25, #36 Elements
# 	 How can I increase the traffic on a site?
# 	 How can I increase a website traffic?
# 	 How can I increase the traffic on my website?
# 	 ...
# 	 How can I increase traffic very soon on my blog?
# 	 How can I increase the organic search traffic to my site?
# 	 How can I increase the traffic on my blog (www.midnightexpressions.wordpress.com)?
#
# Cluster 26, #34 Elements
# 	 How cold can the Gobi Desert get, and how do its average temperatures compare to the ones in the Sahara?
# 	 How cold can the Gobi Desert get, and how do its average temperatures compare to the ones in the Arabian Desert?
# 	 How cold can the Gobi Desert get, and how do its average temperatures compare to the ones in the Great Sandy Desert?
# 	 ...
# 	 What is the Sahara, and how do the average temperatures there compare to the ones in the Dasht-e Loot?
# 	 What is the Sahara, and how do the average temperatures there compare to the ones in the Colorado Plateau?
# 	 What is the Sahara, and how do the average temperatures there compare to the ones in the Antarctica?
#
# Cluster 27, #33 Elements
# 	 What are the strongest majors in terms of job prospects and what are the weakest majors at Texas A&M?
# 	 What are the strongest majors in terms of job prospects and what are the weakest majors at Morehead State?
# 	 What are the strongest majors in terms of job prospects and what are the weakest majors at CMU?
# 	 ...
# 	 What are the strongest majors in terms of job prospects and what are the weakest majors at Sheridan College?
# 	 What are the strongest majors in terms of job prospects and what are the weakest majors at Franklin University?
# 	 What are the strongest majors in terms of job prospects and what are the weakest majors at Westminster College?
#
# Cluster 28, #33 Elements
# 	 What are some tips on making it through the job interview process at First Solar?
# 	 What are some tips on making it through the job interview process at Dexcom?
# 	 What are some tips on making it through the job interview process at Banner?
# 	 ...
# 	 What are some tips on making it through the job interview process at Progress Software?
# 	 What are some tips on making it through the job interview process at Republic Bank?
# 	 What are some tips on making it through the job interview process at The New York Times?
#
# Cluster 29, #33 Elements
# 	 How do I concentrate in a better way on studies?
# 	 How do I concentrate better in my studies?
# 	 How do I concentrate in studies?
# 	 ...
# 	 How do I stay focused on academics?
# 	 How can one study most effectively?
# 	 How do I study properly?
#
# Cluster 30, #33 Elements
# 	 What is most embarrassing moment of your life?
# 	 What is the best embarrassing moment of your life?
# 	 What are the embarrassing moment of your life?
# 	 ...
# 	 What's the most embarrassing thing that happened to you on a date?
# 	 What is the most embarrassing moment in Olympic history?
# 	 What is the most annoying moment of your life?
#
# Cluster 31, #32 Elements
# 	 What's the importance of GST bill in India?
# 	 Why does gst bill is important?
# 	 What is GST Bill ? Why it is so important for Government ?
# 	 ...
# 	 How GST will affect Indian economy after it is enacted?
# 	 Do you think the passing of the GST bill proposed by the BJP would enhance the economy and would it be beneficial to the common man? If so, how would it serve as a surplus to the country?
# 	 What is going to be the impact of the GST on the Indian economy and finance?
#
# Cluster 32, #32 Elements
# 	 How do I hack WhatsApp?
# 	 How can I hack whatsapp?
# 	 What is the way to hack WhatsApp?
# 	 ...
# 	 How do I use WhatsApp?
# 	 Can you hack my crush's WhatsApp account for me?
# 	 How do I know if my WhatsApp account has been hacked?
#
# Cluster 33, #32 Elements
# 	 How do I get into my Instagram if I forgot my email and my Facebook password?
# 	 I forgot my Instagram password. How can I get into my account?
# 	 How do I verify my Instagram account if I've forgotten the password of my email?
# 	 ...
# 	 How do you hack into Instagram?
# 	 How do you get your Instagram back, once you've been hacked?
# 	 How can I get back in my Facebook without a vaild email or password?
#
# Cluster 34, #31 Elements
# 	 How do I stop my addiction to porn and masturbation?
# 	 How do I stop addiction to porn?
# 	 How can I stop my porn addiction?
# 	 ...
# 	 How do I stop masturbating?
# 	 How do I permanently quit pornography?
# 	 How did you overcome porn addiction?
#
# Cluster 35, #30 Elements
# 	 How can I start preparing for ias exam? I have 4 yrs.
# 	 I wanna start preparing for ias exam, how should I proceed?
# 	 How should I start my preparation for the IAS exam?
# 	 ...
# 	 How can I start preparing for civil service examination?
# 	 Should IAS preparation start after graduation?
# 	 I want to appear in the IAS 2018. How do I prepare while studying 8 hrs a day?
#
# Cluster 36, #30 Elements
# 	 Can you see who viewed your Instagram?
# 	 Can you see who views your Instagram?
# 	 Can you see who view your Instagram?
# 	 ...
# 	 Who viewed my video on Instagram?
# 	 Can you really see who viewed your profile on Facebook?
# 	 On Instagram can you now see how many times someone has watched your video?
#
# Cluster 37, #30 Elements
# 	 How did Donald Trump win your vote?
# 	 How did Donald Trump win the election?
# 	 How did Donald trump win the elections?
# 	 ...
# 	 If you voted for Donald Trump, why did you vote for him?
# 	 What do you think of Donald Trump winning the US Presidential election?
# 	 How did Donald Trump become president?
#
# Cluster 38, #29 Elements
# 	 What is the scariest paranormal experience you have ever had?
# 	 What is the scariest paranormal experience you've ever had?
# 	 What are the creepiest paranormal experience you have had?
# 	 ...
# 	 What was the scariest story you ever heard?
# 	 What was your scariest nightmare?
# 	 What is the scariest you have ever heard or read?
#
# Cluster 39, #29 Elements
# 	 What affects India if Donald Trump becomes president?
# 	 What Can happen to India if Donald Trump becomes president?
# 	 What will be the effect of Donald Trump becoming the president of US on India?
# 	 ...
# 	 How good/bad will it be for India if Trump wins the election?
# 	 What does Donald Trump think of India?
# 	 What will happen if Donald Trump became the president of America?
#
# Cluster 40, #29 Elements
# 	 What is the best way to get rid of acne?
# 	 How can I get rid of my acne?
# 	 How do I get rid of acne naturally?
# 	 ...
# 	 How do I get rid of acne on my face? I workout daily and wash my face twice a day.
# 	 How did you get rid of acne scars on face?
# 	 How do I make skin free from acne for boys?
#
# Cluster 41, #29 Elements
# 	 How did you managed long distance relationship?
# 	 How can long distance relationships be successful?
# 	 How are long distance relationships maintained?
# 	 ...
# 	 Why do long distance relationships fail?
# 	 Can somebody tell me a story of a successful long distance relationship that turned into a marriage?
# 	 Do long distance relationships ever work out?
#
# Cluster 42, #28 Elements
# 	 What are the safety precautions on handling shotguns proposed by the NRA in Iowa?
# 	 What are the safety precautions on handling shotguns proposed by the NRA in Illinois?
# 	 What are the safety precautions on handling shotguns proposed by the NRA in Idaho?
# 	 ...
# 	 What are the safety precautions on handling shotguns proposed by the NRA in Utah?
# 	 What are the safety precautions on handling shotguns proposed by the NRA in Hawaii?
# 	 What are the safety precautions on handling shotguns proposed by the NRA in Rhode Island?
#
# Cluster 43, #28 Elements
# 	 How does having sex feel for the first time?
# 	 How does sex feel like for the first time?
# 	 How does sex for the first time feel like?
# 	 ...
# 	 What does sex feel like from a man's prespective?
# 	 What was your first sexual experience like?
# 	 What was your first sex experience?
#
# Cluster 44, #28 Elements
# 	 What are the best horror movies of 2016?
# 	 What are some best horror movies of 2016?
# 	 Which were the best horror films of 2016?
# 	 ...
# 	 What is your best 2016 movie?
# 	 What has been the best movie of 2016?
# 	 What are the best horror movies that will keep you up at night?
#
# Cluster 45, #28 Elements
# 	 What are the best places to visit in Kerala?
# 	 What are the best places to visit in Kerala for 3 to 4 days?
# 	 What are the best places to visit on a 3 day trip in and around kerala?
# 	 ...
# 	 Is it advisable to visit Kerala in June?
# 	 How was your experience while travelling in Kerala?
# 	 Which is the best beach in Kerala? Kindly provide the reasons for it.
#
# Cluster 46, #28 Elements
# 	 Which are best places to visit in GOA during vacations?
# 	 What are the best places to visit in Goa?
# 	 What are all the best places to visit in goa?
# 	 ...
# 	 What are the must do things on Goa for my solo trip this January?
# 	 What are some budget friendly tips like where to stay and all, for a 2 night visit to Goa?
# 	 How can I plan a 3 days/3 nights trip to Goa?
#
# Cluster 47, #27 Elements
# 	 Can you make money from YouTube?
# 	 How can I make money from YouTube?
# 	 How can I make money through YouTube?
# 	 ...
# 	 I need to make money real quick. Should I start a YouTube career?
# 	 Is there any need of money to upload videos on YouTube?
# 	 How much does it take to make $100k on YouTube?
#
# Cluster 48, #27 Elements
# 	 If I want to invest in the stock market, how I start?
# 	 How can I get started in stock market?
# 	 How do you join and start investing into the stock market?
# 	 ...
# 	 What is the best way to learn about stock market?
# 	 I'm 18 and want to learn the stock market how could I teach myself the basics?
# 	 What are the ways to learn about stock market?
#
# Cluster 49, #27 Elements
# 	 Which is the best course for digital marketing?
# 	 Which is the best digital marketing course?
# 	 Which is best digital marketing course?
# 	 ...
# 	 Digital Marketing colleges in India?
# 	 What are some CV worthy online Digital Marketing courses?
# 	 I am MBA (Marketing) Student. I want to pursue Digital marketing Course. So where Can I find best course of Digital Marketing? Is there any Institute in Mumbai who are providing the Digital marketing Course?
#
# Cluster 50, #27 Elements
# 	 What are the best in the ear headphones under 2000?
# 	 What are the Best earphones under 2000₹?
# 	 What are some good over ear headphones under 2000?
# 	 ...
# 	 What are some good earphones for under $60?
# 	 What are the best earphones under 60$?
# 	 Which is the best earphone with deep bass under 1000?
#
# Cluster 51, #27 Elements
# 	 Which is the best career option after mechanical engineering?
# 	 What are my options after mechanical engineering?
# 	 What can I do after BE mechanical engineering?
# 	 ...
# 	 What are career option and job opportunities for mechanical engineering (graduate) student in Germany?
# 	 What are the career options after electrical and electronics engineering?
# 	 What are all the available options for government jobs after completing B.Tech in mechanical engineering?
#
# Cluster 52, #27 Elements
# 	 What are good gifts for a foreign visitor to bring when they're invited to someone's home in Anguilla for the first time?
# 	 What are good gifts for a foreign visitor to bring when they're invited to someone's home in Philippines for the first time?
# 	 What are good gifts for a foreign visitor to bring when they're invited to someone's home in Mexico for the first time?
# 	 ...
# 	 What are good gifts for a foreign visitor to bring when they're invited to someone's home in Egypt for the first time?
# 	 What are good gifts for a foreign visitor to bring when they're invited to someone's home in Moldova for the first time?
# 	 What are good gifts for a foreign visitor to bring when they're invited to someone's home in Poland for the first time?
#
# Cluster 53, #27 Elements
# 	 What are some mind blowing technology gadgets that most people don't know?
# 	 What are some mind-blowing gadgets and technologies that exist that most people don't know about?
# 	 What are some mind blowing technology tools that most people don't know?
# 	 ...
# 	 What are some mind-blowing Hologram gadgets that exist that most people don't know about?
# 	 What are some mind-blowing car accessories that exist that most people don't know about?
# 	 What are some mind-blowing wallets gadgets that exist that most people don't know about?
#
# Cluster 54, #26 Elements
# 	 How can one reduce hairfall?
# 	 How can I reduce hairfall?
# 	 What should do to reduce hair fall?
# 	 ...
# 	 What are the best options for hair loss?
# 	 How do I stop dandruff and hairfall?
# 	 What are home remedies for hair loss?
#
# Cluster 55, #26 Elements
# 	 How should I begin learning Python?
# 	 How should I start learning Python?
# 	 How do I learn Python?
# 	 ...
# 	 Is Python easy to learn?
# 	 Which is the best book for learning Python 3 for absolute beginners?
# 	 How do I improve my python coding skills?
#
# Cluster 56, #26 Elements
# 	 What are best Hollywood movies?
# 	 What are the best movies of Hollywood?
# 	 What are some of the best Hollywood movies to watch?
# 	 ...
# 	 What are the best thriller movie in Hollywood?
# 	 Which are best Hollywood song?
# 	 What are the best movies of all time?
#
# Cluster 57, #26 Elements
# 	 What should i do to overcome depression ?
# 	 How should I overcome my depression?
# 	 How do I deal with depression?
# 	 ...
# 	 How can I escape from my depression?
# 	 How can you come out of depression?
# 	 Can you share any good tips to fight depression?
#
# Cluster 58, #26 Elements
# 	 How can I add pictures on Quora?
# 	 How do I add photos on Quora?
# 	 How do I add images in Quora?
# 	 ...
# 	 How can I upload my profile picture in Quora?
# 	 How do I insert an image in an answer or question details on Quora?
# 	 How do I use my picture as my profile picture on Quora?
#
# Cluster 59, #26 Elements
# 	 Which is the best laptop to buy under 50k?
# 	 Which laptop is best under 50K now a days?
# 	 Which laptop should I buy for 50k INR?
# 	 ...
# 	 Which is the best gaming laptop under 60k INR?
# 	 What is the best laptop under 30k?
# 	 Which is the best laptop model to buy within 30k?
#
# Cluster 60, #26 Elements
# 	 If dark/vacuum energy is created with expansion and it has no limit, could infinite energy be created then?
# 	 If dark/vacuum energy is created with expansion and it has no limit, can infinite energy be created then?
# 	 Can an infinite amount of dark or vacuum or gravitational energy be created with expansion?
# 	 ...
# 	 Since more and more dark energy appears does this mean that it is infinite or that the potential dark energy that can be created is infinite?
# 	 If universe expands without limit is there infinite potential energy that transforms into kinetic energy (of expansion) all the time?
# 	 Does universe expand because of some energy? And if yes and expansion has no limit, is that energy infinite or at least potentially infinite?
#
# Cluster 61, #25 Elements
# 	 Why is Saltwater taffy candy imported in the Philippines?
# 	 Why is Saltwater taffy candy imported in The Bahamas?
# 	 Why is Saltwater Taffy candy imported in Portugal?
# 	 ...
# 	 Why is Saltwater taffy candy imported in Germany?
# 	 Why are saltwater taffy imported in Japan?
# 	 Why is salt water taffy candy unknown in Japan?
#
# Cluster 62, #25 Elements
# 	 What is the best hilarious joke you have ever heard?
# 	 What is the most funny joke you have ever heard?
# 	 Which is the best joke you have ever heard?
# 	 ...
# 	 What's the funniest highbrow joke you've ever heard?
# 	 What is the best joke you've ever heard? Please keep it clean.
# 	 What are the all time best jokes?
#
# Cluster 63, #25 Elements
# 	 What is your biggest mistake or regret?
# 	 What is your biggest regret of your life?
# 	 What is the biggest mistake you have ever made in your life and regret it alot?
# 	 ...
# 	 What is the biggest mistake you made in your 30s and what did you learn from it?
# 	 What is the biggest mistake you have ever made at work?
# 	 Some of the biggest mistake in life?
